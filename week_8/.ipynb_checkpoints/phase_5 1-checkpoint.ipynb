# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    SimpleRNN,
    LSTM,
    GRU,
    Bidirectional,
    Dense,
    Dropout
)
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau
)
import joblib
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786270063.140638   40439 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1786270063.239330   40439 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786270065.194165   40439 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
df = pd.read_csv("PJME_preprocessed.csv",)

# %%
df.head()
# Out:
#               Datetime  PJME_MW  Hour  Day  DayOfWeek  Month  Year  Week  \
# 0  2002-01-08 01:00:00  29445.0     1    8          1      1  2002     2
# 1  2002-01-08 02:00:00  28670.0     2    8          1      1  2002     2
# 2  2002-01-08 03:00:00  28375.0     3    8          1      1  2002     2
# 3  2002-01-08 04:00:00  28542.0     4    8          1      1  2002     2
# 4  2002-01-08 05:00:00  29261.0     5    8          1      1  2002     2
#
#    IsWeekend  Season  ...  Month_sin  Month_cos    Lag_1   Lag_24   Lag_48  \
# 0          0  Winter  ...        0.5   0.866025  31187.0  26862.0  27100.0
# 1          0  Winter  ...        0.5   0.866025  29445.0  25976.0  26097.0
# 2          0  Winter  ...        0.5   0.866025  28670.0  25641.0  25793.0
# 3          0  Winter  ...        0.5   0.866025  28375.0  25666.0  25657.0
# 4          0  Winter  ...        0.5   0.866025  28542.0  26328.0  25778.0
#
#    Lag_168  RollingMean_24  RollingMean_168  RollingStd_24  RollingStd_168
# 0  30393.0    33560.208333     32513.869048    4425.965952     3861.770954
# 1  29265.0    33672.458333     32510.327381    4256.159403     3865.039821
# 2  28357.0    33786.375000     32510.434524    4064.104959     3864.924245
# 3  27899.0    33906.208333     32514.261905    3851.076461     3860.646270
# 4  28057.0    34028.416667     32521.428571    3640.941409     3853.433314
#
# [5 rows x 24 columns]

# %%
target = "PJME_MW"

# %%
df[target].describe()
# Out:
# count    145224.000000
# mean      32078.417972
# std        6466.680687
# min       14544.000000
# 25%       27569.000000
# 50%       31419.000000
# 75%       35647.000000
# max       62009.000000
# Name: PJME_MW, dtype: float64

# %%
df[target].isnull().sum()
# Out:
# np.int64(0)

# %%
n = len(df)
test_size = int(n * 0.20)
test_start = n - test_size

# %%
validation_hours = 60 * 24
validation_start = (test_start - validation_hours)

# %%
train_df = df.iloc[:validation_start].copy()
validation_df = df.iloc[validation_start:test_start].copy()
test_df = df.iloc[test_start:].copy()

# %%
print("Train:", train_df.shape)
print("Validation:", validation_df.shape)
print("Test:", test_df.shape)
# Out:
# Train: (114740, 24)
# Validation: (1440, 24)
# Test: (29044, 24)

# %%
train_values = train_df[[target]].values
validation_values = validation_df[[target]].values
test_values = test_df[[target]].values

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_values)
validation_scaled = scaler.transform(validation_values)
test_scaled = scaler.transform(test_values)

# %%
print(
    train_scaled.min(),
    train_scaled.max()
)
# Out:
# 0.0 1.0

# %%
LOOKBACKS = [24, 48, 168]
HORIZON = 24

# %%
def create_sequences(data,lookback,horizon):
    X = []
    y = []
    for i in range(lookback,len(data) - horizon + 1):
        X.append(data[i - lookback:i])
        y.append(data[i:i + horizon,0])
    return (np.array(X),np.array(y))

# %%
X_train_rnn_24, y_train_rnn_24 = create_sequences(
    train_scaled,
    24,
    24
)

# %%
print("X shape:", X_train_rnn_24.shape)
print("y shape:", y_train_rnn_24.shape)
# Out:
# X shape: (114693, 24, 1)
# y shape: (114693, 24)

# %%
X_train_rnn_48, y_train_rnn_48 = create_sequences(
    train_scaled,
    48,
    24
)

# %%
print("X shape:", X_train_rnn_48.shape)
print("y shape:", y_train_rnn_48.shape)
# Out:
# X shape: (114669, 48, 1)
# y shape: (114669, 24)

# %%
X_train_rnn_168, y_train_rnn_168 = create_sequences(
    train_scaled,
    168,
    24
)

# %%
print("X shape:", X_train_rnn_168.shape)
print("y shape:", y_train_rnn_168.shape)
# Out:
# X shape: (114549, 168, 1)
# y shape: (114549, 24)

# %%
def build_rnn(lookback):
    model = Sequential([
        SimpleRNN(
            64,
            input_shape=(lookback, 1)
        ),
        Dense(
            64,
            activation="relu"
        ),
        Dense(24)
    ])
    model.compile(
        optimizer="adam",
        loss="mse",
        metrics=["mae"]
    )
    return model

# %%
rnn_24 = build_rnn(24)
# Out:
# E0000 00:00:1786270067.230122   40439 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/aximsoft/.local/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
rnn_24.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,944 (38.84 KB)
#  Trainable params: 9,944 (38.84 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_rnn_24 = rnn_24.fit(
    X_train_rnn_24,
    y_train_rnn_24,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0051 - mae: 0.0522 - val_loss: 0.0061 - val_mae: 0.0598
# Epoch 2/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0030 - mae: 0.0411 - val_loss: 0.0062 - val_mae: 0.0597
# Epoch 3/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0029 - mae: 0.0402 - val_loss: 0.0049 - val_mae: 0.0532
# Epoch 4/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0028 - mae: 0.0392 - val_loss: 0.0053 - val_mae: 0.0549
# Epoch 5/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0027 - mae: 0.0383 - val_loss: 0.0049 - val_mae: 0.0521
# Epoch 6/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - mae: 0.0377 - val_loss: 0.0046 - val_mae: 0.0505
# Epoch 7/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0025 - mae: 0.0371 - val_loss: 0.0043 - val_mae: 0.0486
# Epoch 8/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0025 - mae: 0.0367 - val_loss: 0.0043 - val_mae: 0.0480
# Epoch 9/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0024 - mae: 0.0364 - val_loss: 0.0041 - val_mae: 0.0471
# Epoch 10/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0024 - mae: 0.0361 - val_loss: 0.0043 - val_mae: 0.0481

# %%
rnn_48 = build_rnn(48)

# %%
history_rnn_48 = rnn_48.fit(
    X_train_rnn_48,
    y_train_rnn_48,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - loss: 0.0056 - mae: 0.0542 - val_loss: 0.0074 - val_mae: 0.0651
# Epoch 2/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0032 - mae: 0.0422 - val_loss: 0.0073 - val_mae: 0.0651
# Epoch 3/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0029 - mae: 0.0398 - val_loss: 0.0061 - val_mae: 0.0580
# Epoch 4/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0027 - mae: 0.0384 - val_loss: 0.0048 - val_mae: 0.0523
# Epoch 5/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0026 - mae: 0.0376 - val_loss: 0.0043 - val_mae: 0.0490
# Epoch 6/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0025 - mae: 0.0371 - val_loss: 0.0044 - val_mae: 0.0495
# Epoch 7/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0025 - mae: 0.0372 - val_loss: 0.0053 - val_mae: 0.0548
# Epoch 8/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0025 - mae: 0.0367 - val_loss: 0.0047 - val_mae: 0.0510
# Epoch 9/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0025 - mae: 0.0365 - val_loss: 0.0043 - val_mae: 0.0489
# Epoch 10/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0025 - mae: 0.0363 - val_loss: 0.0043 - val_mae: 0.0484

# %%
rnn_168 = build_rnn(168)

# %%
history_rnn_168 = rnn_168.fit(
    X_train_rnn_168,
    y_train_rnn_168,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - loss: 0.0053 - mae: 0.0516 - val_loss: 0.0072 - val_mae: 0.0635
# Epoch 2/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0029 - mae: 0.0397 - val_loss: 0.0047 - val_mae: 0.0515
# Epoch 3/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0027 - mae: 0.0384 - val_loss: 0.0063 - val_mae: 0.0589
# Epoch 4/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0027 - mae: 0.0383 - val_loss: 0.0061 - val_mae: 0.0574
# Epoch 5/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0027 - mae: 0.0380 - val_loss: 0.0049 - val_mae: 0.0512
# Epoch 6/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0026 - mae: 0.0371 - val_loss: 0.0039 - val_mae: 0.0455
# Epoch 7/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0025 - mae: 0.0365 - val_loss: 0.0042 - val_mae: 0.0471
# Epoch 8/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0026 - mae: 0.0375 - val_loss: 0.0037 - val_mae: 0.0437
# Epoch 9/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0024 - mae: 0.0362 - val_loss: 0.0037 - val_mae: 0.0441
# Epoch 10/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0028 - mae: 0.0384 - val_loss: 0.0045 - val_mae: 0.0490

# %%
def build_lstm(lookback):
    model = Sequential([
        LSTM(
            64,
            input_shape=(lookback, 1)
        ),
        Dense(
            64,
            activation="relu"
        ),
        Dense(24)
    ])
    model.compile(
        optimizer="adam",
        loss="mse",
        metrics=["mae"]
    )
    return model

# %%
X_train_lstm_24, y_train_lstm_24 = create_sequences(
    train_scaled,
    24,
    24
)

# %%
lstm_24 = build_lstm(24)
lstm_24.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,616 (88.34 KB)
#  Trainable params: 22,616 (88.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_lstm_24 = lstm_24.fit(
    X_train_lstm_24,
    y_train_lstm_24,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - loss: 0.0071 - mae: 0.0632 - val_loss: 0.0091 - val_mae: 0.0734
# Epoch 2/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 0.0039 - mae: 0.0482 - val_loss: 0.0077 - val_mae: 0.0665
# Epoch 3/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 0.0036 - mae: 0.0454 - val_loss: 0.0060 - val_mae: 0.0583
# Epoch 4/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 0.0030 - mae: 0.0407 - val_loss: 0.0050 - val_mae: 0.0526
# Epoch 5/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 0.0027 - mae: 0.0390 - val_loss: 0.0047 - val_mae: 0.0506
# Epoch 6/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 0.0027 - mae: 0.0384 - val_loss: 0.0047 - val_mae: 0.0500
# Epoch 7/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 0.0026 - mae: 0.0380 - val_loss: 0.0047 - val_mae: 0.0505
# Epoch 8/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 0.0026 - mae: 0.0378 - val_loss: 0.0046 - val_mae: 0.0500
# Epoch 9/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - loss: 0.0026 - mae: 0.0377 - val_loss: 0.0046 - val_mae: 0.0500
# Epoch 10/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 0.0026 - mae: 0.0375 - val_loss: 0.0046 - val_mae: 0.0497

# %%
X_train_lstm_48, y_train_lstm_48 = create_sequences(
    train_scaled,
    48,
    24
)

# %%
lstm_48 = build_lstm(48)

# %%
history_lstm_48 = lstm_48.fit(
    X_train_lstm_48,
    y_train_lstm_48,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 0.0066 - mae: 0.0611 - val_loss: 0.0082 - val_mae: 0.0700
# Epoch 2/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - loss: 0.0035 - mae: 0.0456 - val_loss: 0.0063 - val_mae: 0.0600
# Epoch 3/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0057 - val_mae: 0.0570
# Epoch 4/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - loss: 0.0028 - mae: 0.0398 - val_loss: 0.0052 - val_mae: 0.0539
# Epoch 5/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - loss: 0.0027 - mae: 0.0389 - val_loss: 0.0047 - val_mae: 0.0510
# Epoch 6/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - loss: 0.0027 - mae: 0.0385 - val_loss: 0.0047 - val_mae: 0.0513
# Epoch 7/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - loss: 0.0027 - mae: 0.0384 - val_loss: 0.0044 - val_mae: 0.0504
# Epoch 8/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - loss: 0.0027 - mae: 0.0384 - val_loss: 0.0044 - val_mae: 0.0503
# Epoch 9/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - loss: 0.0027 - mae: 0.0384 - val_loss: 0.0045 - val_mae: 0.0515
# Epoch 10/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - loss: 0.0027 - mae: 0.0383 - val_loss: 0.0044 - val_mae: 0.0504

# %%
X_train_lstm_168, y_train_lstm_168 = create_sequences(
    train_scaled,
    168,
    24
)

# %%
lstm_168 = build_lstm(168)

# %%
history_lstm_168 = lstm_168.fit(
    X_train_lstm_168,
    y_train_lstm_168,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 103s 63ms/step - loss: 0.0066 - mae: 0.0600 - val_loss: 0.0077 - val_mae: 0.0680
# Epoch 2/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 102s 63ms/step - loss: 0.0034 - mae: 0.0445 - val_loss: 0.0074 - val_mae: 0.0656
# Epoch 3/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 102s 63ms/step - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0069 - val_mae: 0.0623
# Epoch 4/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 102s 63ms/step - loss: 0.0031 - mae: 0.0419 - val_loss: 0.0062 - val_mae: 0.0585
# Epoch 5/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 102s 63ms/step - loss: 0.0029 - mae: 0.0406 - val_loss: 0.0060 - val_mae: 0.0583
# Epoch 6/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 101s 63ms/step - loss: 0.0028 - mae: 0.0399 - val_loss: 0.0054 - val_mae: 0.0554
# Epoch 7/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 101s 63ms/step - loss: 0.0028 - mae: 0.0395 - val_loss: 0.0053 - val_mae: 0.0540
# Epoch 8/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 101s 63ms/step - loss: 0.0028 - mae: 0.0392 - val_loss: 0.0048 - val_mae: 0.0519
# Epoch 9/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 101s 63ms/step - loss: 0.0027 - mae: 0.0385 - val_loss: 0.0044 - val_mae: 0.0501
# Epoch 10/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 102s 64ms/step - loss: 0.0026 - mae: 0.0378 - val_loss: 0.0045 - val_mae: 0.0502

# %%
def build_gru(lookback):
    model = Sequential([
        GRU(
            64,
            input_shape=(lookback, 1)
        ),
        Dense(
            64,
            activation="relu"
        ),
        Dense(24)
    ])
    model.compile(
        optimizer="adam",
        loss="mse",
        metrics=["mae"]
    )
    return model

# %%
X_train_gru_24, y_train_gru_24 = create_sequences(
    train_scaled,
    24,
    24
)

# %%
gru_24 = build_gru(24)

# %%
history_gru_24 = gru_24.fit(
    X_train_gru_24,
    y_train_gru_24,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - loss: 0.0071 - mae: 0.0629 - val_loss: 0.0094 - val_mae: 0.0745
# Epoch 2/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 0.0038 - mae: 0.0475 - val_loss: 0.0082 - val_mae: 0.0691
# Epoch 3/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 0.0036 - mae: 0.0459 - val_loss: 0.0082 - val_mae: 0.0687
# Epoch 4/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0062 - val_mae: 0.0593
# Epoch 5/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 0.0028 - mae: 0.0398 - val_loss: 0.0055 - val_mae: 0.0558
# Epoch 6/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0027 - mae: 0.0389 - val_loss: 0.0050 - val_mae: 0.0529
# Epoch 7/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0026 - mae: 0.0384 - val_loss: 0.0048 - val_mae: 0.0512
# Epoch 8/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0026 - mae: 0.0380 - val_loss: 0.0047 - val_mae: 0.0509
# Epoch 9/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0026 - mae: 0.0378 - val_loss: 0.0045 - val_mae: 0.0499
# Epoch 10/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0026 - mae: 0.0377 - val_loss: 0.0043 - val_mae: 0.0485

# %%
X_train_gru_48, y_train_gru_48 = create_sequences(
    train_scaled,
    48,
    24
)

# %%
gru_48 = build_gru(48)

# %%
history_gru_48 = gru_48.fit(
    X_train_gru_48,
    y_train_gru_48,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 39s 23ms/step - loss: 0.0073 - mae: 0.0637 - val_loss: 0.0084 - val_mae: 0.0706
# Epoch 2/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 37s 23ms/step - loss: 0.0036 - mae: 0.0463 - val_loss: 0.0078 - val_mae: 0.0675
# Epoch 3/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 37s 23ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0066 - val_mae: 0.0625
# Epoch 4/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0029 - mae: 0.0400 - val_loss: 0.0060 - val_mae: 0.0590
# Epoch 5/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0028 - mae: 0.0395 - val_loss: 0.0056 - val_mae: 0.0576
# Epoch 6/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0028 - mae: 0.0394 - val_loss: 0.0056 - val_mae: 0.0573
# Epoch 7/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0027 - mae: 0.0391 - val_loss: 0.0052 - val_mae: 0.0554
# Epoch 8/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0027 - mae: 0.0388 - val_loss: 0.0046 - val_mae: 0.0515
# Epoch 9/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0027 - mae: 0.0387 - val_loss: 0.0052 - val_mae: 0.0554
# Epoch 10/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0027 - mae: 0.0387 - val_loss: 0.0050 - val_mae: 0.0541

# %%
X_train_gru_168, y_train_gru_168 = create_sequences(
    train_scaled,
    168,
    24
)

# %%
gru_168 = build_gru(168)

# %%
history_gru_168 = gru_168.fit(
    X_train_gru_168,
    y_train_gru_168,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 128s 78ms/step - loss: 0.0077 - mae: 0.0649 - val_loss: 0.0075 - val_mae: 0.0659
# Epoch 2/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 128s 80ms/step - loss: 0.0036 - mae: 0.0454 - val_loss: 0.0067 - val_mae: 0.0608
# Epoch 3/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 127s 79ms/step - loss: 0.0034 - mae: 0.0438 - val_loss: 0.0065 - val_mae: 0.0601
# Epoch 4/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 127s 79ms/step - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0065 - val_mae: 0.0604
# Epoch 5/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 127s 79ms/step - loss: 0.0030 - mae: 0.0413 - val_loss: 0.0063 - val_mae: 0.0594
# Epoch 6/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 127s 79ms/step - loss: 0.0029 - mae: 0.0405 - val_loss: 0.0064 - val_mae: 0.0614
# Epoch 7/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 128s 79ms/step - loss: 0.0030 - mae: 0.0412 - val_loss: 0.0073 - val_mae: 0.0662
# Epoch 8/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 127s 79ms/step - loss: 0.0031 - mae: 0.0421 - val_loss: 0.0071 - val_mae: 0.0653
# Epoch 9/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 128s 79ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0063 - val_mae: 0.0604
# Epoch 10/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 128s 79ms/step - loss: 0.0034 - mae: 0.0436 - val_loss: 0.0061 - val_mae: 0.0605

# %%
def build_bilstm(lookback):
    model = Sequential([
        Bidirectional(
            LSTM(
                64
            ),
            input_shape=(lookback, 1)
        ),
        Dense(
            64,
            activation="relu"
        ),
        Dense(24)
    ])
    model.compile(
        optimizer="adam",
        loss="mse",
        metrics=["mae"]
    )
    return model

# %%
X_train_bilstm_24, y_train_bilstm_24 = create_sequences(
    train_scaled,
    24,
    24
)

# %%
bilstm_24 = build_bilstm(24)
# Out:
# /home/aximsoft/.local/lib/python3.12/site-packages/keras/src/layers/rnn/bidirectional.py:110: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history_bilstm_24 = bilstm_24.fit(
    X_train_bilstm_24,
    y_train_bilstm_24,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - loss: 0.0061 - mae: 0.0585 - val_loss: 0.0080 - val_mae: 0.0690
# Epoch 2/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0068 - val_mae: 0.0635
# Epoch 3/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0029 - mae: 0.0404 - val_loss: 0.0056 - val_mae: 0.0568
# Epoch 4/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0028 - mae: 0.0395 - val_loss: 0.0052 - val_mae: 0.0537
# Epoch 5/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0027 - mae: 0.0389 - val_loss: 0.0050 - val_mae: 0.0523
# Epoch 6/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0026 - mae: 0.0383 - val_loss: 0.0048 - val_mae: 0.0511
# Epoch 7/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0026 - mae: 0.0377 - val_loss: 0.0046 - val_mae: 0.0505
# Epoch 8/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - loss: 0.0025 - mae: 0.0374 - val_loss: 0.0048 - val_mae: 0.0517
# Epoch 9/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - loss: 0.0025 - mae: 0.0372 - val_loss: 0.0048 - val_mae: 0.0517
# Epoch 10/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - loss: 0.0025 - mae: 0.0372 - val_loss: 0.0048 - val_mae: 0.0520

# %%
X_train_bilstm_48, y_train_bilstm_48 = create_sequences(
    train_scaled,
    48,
    24
)

# %%
bilstm_48 = build_bilstm(48)

# %%
history_bilstm_48 = bilstm_48.fit(
    X_train_bilstm_48,
    y_train_bilstm_48,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 40s 23ms/step - loss: 0.0065 - mae: 0.0611 - val_loss: 0.0087 - val_mae: 0.0717
# Epoch 2/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0034 - mae: 0.0441 - val_loss: 0.0056 - val_mae: 0.0560
# Epoch 3/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 39s 24ms/step - loss: 0.0030 - mae: 0.0407 - val_loss: 0.0054 - val_mae: 0.0550
# Epoch 4/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0029 - mae: 0.0400 - val_loss: 0.0048 - val_mae: 0.0516
# Epoch 5/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0028 - mae: 0.0396 - val_loss: 0.0046 - val_mae: 0.0508
# Epoch 6/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0027 - mae: 0.0390 - val_loss: 0.0043 - val_mae: 0.0491
# Epoch 7/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0027 - mae: 0.0384 - val_loss: 0.0045 - val_mae: 0.0499
# Epoch 8/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - loss: 0.0027 - mae: 0.0383 - val_loss: 0.0043 - val_mae: 0.0490
# Epoch 9/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - loss: 0.0026 - mae: 0.0381 - val_loss: 0.0041 - val_mae: 0.0481
# Epoch 10/10
# 1613/1613 ━━━━━━━━━━━━━━━━━━━━ 39s 24ms/step - loss: 0.0026 - mae: 0.0381 - val_loss: 0.0043 - val_mae: 0.0493

# %%
X_train_bilstm_168, y_train_bilstm_168 = create_sequences(
    train_scaled,
    168,
    24
)

# %%
bilstm_168 = build_bilstm(168)

# %%
history_bilstm_168 = bilstm_168.fit(
    X_train_bilstm_168,
    y_train_bilstm_168,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 120s 73ms/step - loss: 0.0057 - mae: 0.0555 - val_loss: 0.0089 - val_mae: 0.0747
# Epoch 2/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 118s 73ms/step - loss: 0.0030 - mae: 0.0421 - val_loss: 0.0066 - val_mae: 0.0640
# Epoch 3/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 118s 73ms/step - loss: 0.0025 - mae: 0.0376 - val_loss: 0.0057 - val_mae: 0.0583
# Epoch 4/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 118s 73ms/step - loss: 0.0023 - mae: 0.0356 - val_loss: 0.0048 - val_mae: 0.0525
# Epoch 5/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 119s 74ms/step - loss: 0.0022 - mae: 0.0346 - val_loss: 0.0052 - val_mae: 0.0555
# Epoch 6/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 122s 76ms/step - loss: 0.0022 - mae: 0.0345 - val_loss: 0.0052 - val_mae: 0.0559
# Epoch 7/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 158s 98ms/step - loss: 0.0022 - mae: 0.0347 - val_loss: 0.0050 - val_mae: 0.0542
# Epoch 8/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 164s 102ms/step - loss: 0.0023 - mae: 0.0349 - val_loss: 0.0050 - val_mae: 0.0533
# Epoch 9/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 130s 81ms/step - loss: 0.0023 - mae: 0.0352 - val_loss: 0.0052 - val_mae: 0.0544
# Epoch 10/10
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 123s 76ms/step - loss: 0.0023 - mae: 0.0351 - val_loss: 0.0049 - val_mae: 0.0534

# %%
def prepare_validation_data(train_scaled,validation_scaled,lookback,horizon):
    validation_input = np.concatenate([
        train_scaled[-lookback:],
        validation_scaled
    ])
    X_val, y_val = create_sequences(
        validation_input,
        lookback,
        horizon
    )
    return X_val, y_val

# %%
def prepare_test_data(validation_scaled,test_scaled,lookback,horizon):
    test_input = np.concatenate([
        validation_scaled[-lookback:],
        test_scaled
    ])
    X_test, y_test = create_sequences(
        test_input,
        lookback,
        horizon
    )
    return X_test, y_test

# %%
X_val_24, y_val_24 = prepare_validation_data(
    train_scaled,
    validation_scaled,
    24,
    24
)

# %%
X_val_48, y_val_48 = prepare_validation_data(
    train_scaled,
    validation_scaled,
    48,
    24
)

# %%
X_val_168, y_val_168 = prepare_validation_data(
    train_scaled,
    validation_scaled,
    168,
    24
)

# %%
X_test_24, y_test_24 = prepare_test_data(
    validation_scaled,
    test_scaled,
    24,
    24
)

# %%
X_test_48, y_test_48 = prepare_test_data(
    validation_scaled,
    test_scaled,
    48,
    24
)

# %%
X_test_168, y_test_168 = prepare_test_data(
    validation_scaled,
    test_scaled,
    168,
    24
)

# %%
def calculate_metrics(y_actual_scaled, y_pred_scaled, scaler):
    y_actual = scaler.inverse_transform(
        y_actual_scaled.reshape(-1, 1)
    ).reshape(y_actual_scaled.shape)

    y_pred = scaler.inverse_transform(
        y_pred_scaled.reshape(-1, 1)
    ).reshape(y_pred_scaled.shape)
    
    actual = y_actual.flatten()
    predicted = y_pred.flatten()
    
    mae = mean_absolute_error(actual,predicted)
    mse = mean_squared_error(actual,predicted)
    rmse = np.sqrt(mse)
    non_zero = actual != 0
    mape = np.mean(
        np.abs(
            (actual[non_zero] - predicted[non_zero])
            / actual[non_zero]
        )
    ) * 100
    r2 = r2_score(actual,predicted)
    bias = np.mean(predicted - actual)
    return {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "Bias": bias
    }

# %%
rnn_pred_24 = rnn_24.predict(
    X_val_24,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
rnn_24_metrics = calculate_metrics(
    y_val_24,
    rnn_pred_24,
    scaler
)

# %%
rnn_pred_48 = rnn_48.predict(
    X_val_48,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
rnn_48_metrics = calculate_metrics(
    y_val_48,
    rnn_pred_48,
    scaler
)

# %%
rnn_pred_168 = rnn_168.predict(
    X_val_168,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
rnn_168_metrics = calculate_metrics(
    y_val_168,
    rnn_pred_168,
    scaler
)

# %%
rnn_results = pd.DataFrame([
    {
        "Model": "RNN",
        "Lookback": "24 hours",
        **rnn_24_metrics
    },
    {
        "Model": "RNN",
        "Lookback": "48 hours",
        **rnn_48_metrics
    },
    {
        "Model": "RNN",
        "Lookback": "168 hours",
        **rnn_168_metrics
    }
])

# %%
best_rnn_r2 = rnn_results.loc[
    rnn_results["R2"].idxmax()
]
best_rnn_r2
# Out:
# Model                   RNN
# Lookback           48 hours
# MAE             2684.731908
# MSE         12185403.573809
# RMSE            3490.759742
# MAPE               7.833662
# R2                 0.603903
# Bias           -1552.584977
# Name: 1, dtype: object

# %%
lstm_pred_24 = lstm_24.predict(
    X_val_24,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
lstm_24_metrics = calculate_metrics(
    y_val_24,
    lstm_pred_24,
    scaler
)

# %%
lstm_pred_48 = lstm_48.predict(
    X_val_48,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step

# %%
lstm_48_metrics = calculate_metrics(
    y_val_48,
    lstm_pred_48,
    scaler
)

# %%
lstm_pred_168 = lstm_168.predict(
    X_val_168,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %%
lstm_168_metrics = calculate_metrics(
    y_val_168,
    lstm_pred_168,
    scaler
)

# %%
lstm_results = pd.DataFrame([
    {
        "Model": "LSTM",
        "Lookback": "24 hours",
        **lstm_24_metrics
    },
    {
        "Model": "LSTM",
        "Lookback": "48 hours",
        **lstm_48_metrics
    },
    {
        "Model": "LSTM",
        "Lookback": "168 hours",
        **lstm_168_metrics
    }
])

# %%
gru_pred_24 = gru_24.predict(
    X_val_24,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
gru_24_metrics = calculate_metrics(
    y_val_24,
    gru_pred_24,
    scaler
)

# %%
gru_pred_48 = gru_48.predict(
    X_val_48,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
gru_48_metrics = calculate_metrics(
    y_val_48,
    gru_pred_48,
    scaler
)

# %%
gru_pred_168 = gru_168.predict(
    X_val_168,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step

# %%
gru_168_metrics = calculate_metrics(
    y_val_168,
    gru_pred_168,
    scaler
)

# %%
gru_results = pd.DataFrame([
    {
        "Model": "GRU",
        "Lookback": "24 hours",
        **gru_24_metrics
    },
    {
        "Model": "GRU",
        "Lookback": "48 hours",
        **gru_48_metrics
    },
    {
        "Model": "GRU",
        "Lookback": "168 hours",
        **gru_168_metrics
    }
])

# %%
bilstm_pred_24 = bilstm_24.predict(
    X_val_24,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
bilstm_24_metrics = calculate_metrics(
    y_val_24,
    bilstm_pred_24,
    scaler
)

# %%
bilstm_pred_48 = bilstm_48.predict(
    X_val_48,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step

# %%
bilstm_48_metrics = calculate_metrics(
    y_val_48,
    bilstm_pred_48,
    scaler
)

# %%
bilstm_pred_168 = bilstm_168.predict(
    X_val_168,
    verbose=1
)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step

# %%
bilstm_168_metrics = calculate_metrics(
    y_val_168,
    bilstm_pred_168,
    scaler
)

# %%
bilstm_results = pd.DataFrame([
    {
        "Model": "Bi-LSTM",
        "Lookback": "24 hours",
        **bilstm_24_metrics
    },
    {
        "Model": "Bi-LSTM",
        "Lookback": "48 hours",
        **bilstm_48_metrics
    },
    {
        "Model": "Bi-LSTM",
        "Lookback": "168 hours",
        **bilstm_168_metrics
    }
])

# %%
all_results = pd.concat([rnn_results,lstm_results,gru_results,bilstm_results],ignore_index=True)
all_results
# Out:
#       Model   Lookback          MAE           MSE         RMSE       MAPE  \
# 0       RNN   24 hours  2687.357066  1.280694e+07  3578.678163   7.773717
# 1       RNN   48 hours  2684.731908  1.218540e+07  3490.759742   7.833662
# 2       RNN  168 hours  2903.992579  1.447754e+07  3804.935639   8.307286
# 3      LSTM   24 hours  2969.424797  1.526177e+07  3906.631583   8.398609
# 4      LSTM   48 hours  3026.738221  1.504499e+07  3878.786658   8.763176
# 5      LSTM  168 hours  2936.470673  1.508462e+07  3883.892886   8.457236
# 6       GRU   24 hours  2919.180068  1.474307e+07  3839.670798   8.278844
# 7       GRU   48 hours  3261.995561  1.732204e+07  4161.975741   9.331502
# 8       GRU  168 hours  3989.528201  2.495127e+07  4995.124337  11.367106
# 9   Bi-LSTM   24 hours  3062.080161  1.535503e+07  3918.549211   8.694062
# 10  Bi-LSTM   48 hours  2857.792307  1.402632e+07  3745.173017   8.222600
# 11  Bi-LSTM  168 hours  3145.692199  1.634906e+07  4043.397634   8.987282
#
#           R2         Bias
# 0   0.583699 -1366.219501
# 1   0.603903 -1552.584977
# 2   0.529395 -2292.037082
# 3   0.503903 -2507.726473
# 4   0.510949 -2363.282008
# 5   0.509661 -2169.486352
# 6   0.520763 -2329.924394
# 7   0.436932 -2844.605886
# 8   0.188937 -3560.851506
# 9   0.500871 -2565.291698
# 10  0.544062 -1913.283977
# 11  0.468559 -2827.339774

# %%
all_results_sorted = all_results.sort_values(
    by="RMSE",
    ascending=True
).reset_index(drop=True)
all_results_sorted
# Out:
#       Model   Lookback          MAE           MSE         RMSE       MAPE  \
# 0       RNN   48 hours  2684.731908  1.218540e+07  3490.759742   7.833662
# 1       RNN   24 hours  2687.357066  1.280694e+07  3578.678163   7.773717
# 2   Bi-LSTM   48 hours  2857.792307  1.402632e+07  3745.173017   8.222600
# 3       RNN  168 hours  2903.992579  1.447754e+07  3804.935639   8.307286
# 4       GRU   24 hours  2919.180068  1.474307e+07  3839.670798   8.278844
# 5      LSTM   48 hours  3026.738221  1.504499e+07  3878.786658   8.763176
# 6      LSTM  168 hours  2936.470673  1.508462e+07  3883.892886   8.457236
# 7      LSTM   24 hours  2969.424797  1.526177e+07  3906.631583   8.398609
# 8   Bi-LSTM   24 hours  3062.080161  1.535503e+07  3918.549211   8.694062
# 9   Bi-LSTM  168 hours  3145.692199  1.634906e+07  4043.397634   8.987282
# 10      GRU   48 hours  3261.995561  1.732204e+07  4161.975741   9.331502
# 11      GRU  168 hours  3989.528201  2.495127e+07  4995.124337  11.367106
#
#           R2         Bias
# 0   0.603903 -1552.584977
# 1   0.583699 -1366.219501
# 2   0.544062 -1913.283977
# 3   0.529395 -2292.037082
# 4   0.520763 -2329.924394
# 5   0.510949 -2363.282008
# 6   0.509661 -2169.486352
# 7   0.503903 -2507.726473
# 8   0.500871 -2565.291698
# 9   0.468559 -2827.339774
# 10  0.436932 -2844.605886
# 11  0.188937 -3560.851506

# %%
best_r2_model = all_results.loc[
    all_results["R2"].idxmax()
]
print("Best R² Model:")
print(best_r2_model)
# Out:
# Best R² Model:
# Model                   RNN
# Lookback           48 hours
# MAE             2684.731908
# MSE         12185403.573809
# RMSE            3490.759742
# MAPE               7.833662
# R2                 0.603903
# Bias           -1552.584977
# Name: 1, dtype: object

# %%
all_results.to_csv(
    "phase5_validation_results.csv",
    index=False
)

# %%
rnn_test_pred_24 = rnn_24.predict(
    X_test_24,
    verbose=1
)
rnn_test_24_metrics = calculate_metrics(
    y_test_24,
    rnn_test_pred_24,
    scaler
)
rnn_test_24_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# {'MAE': 2181.119019004759,
#  'MSE': 9167739.989144966,
#  'RMSE': np.float64(3027.8276022826935),
#  'MAPE': np.float64(6.664844165669469),
#  'R2': 0.7822156412624903,
#  'Bias': np.float64(-970.7450845944755)}

# %%
rnn_test_pred_48 = rnn_48.predict(
    X_test_48,
    verbose=1
)
rnn_test_48_metrics = calculate_metrics(
    y_test_48,
    rnn_test_pred_48,
    scaler
)
rnn_test_48_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# {'MAE': 2207.6658429630115,
#  'MSE': 8984924.213966422,
#  'RMSE': np.float64(2997.4863158931053),
#  'MAPE': np.float64(6.8075612485329575),
#  'R2': 0.7865585236317004,
#  'Bias': np.float64(-1133.3196032014218)}

# %%
rnn_test_pred_168 = rnn_168.predict(
    X_test_168,
    verbose=1
)
rnn_test_168_metrics = calculate_metrics(
    y_test_168,
    rnn_test_pred_168,
    scaler
)
rnn_test_168_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step
# {'MAE': 2215.833607728294,
#  'MSE': 9626966.709946094,
#  'RMSE': np.float64(3102.735359315405),
#  'MAPE': np.float64(6.6793716530452585),
#  'R2': 0.7713064753150243,
#  'Bias': np.float64(-1378.1263170015893)}

# %%
lstm_test_pred_24 = lstm_24.predict(
    X_test_24,
    verbose=1
)
lstm_test_24_metrics = calculate_metrics(
    y_test_24,
    lstm_test_pred_24,
    scaler
)
lstm_test_24_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# {'MAE': 2253.0353961282663,
#  'MSE': 10016966.262509165,
#  'RMSE': np.float64(3164.9591249349755),
#  'MAPE': np.float64(6.703247134603872),
#  'R2': 0.7620418362040293,
#  'Bias': np.float64(-1544.931532044212)}

# %%
lstm_test_pred_48 = lstm_48.predict(
    X_test_48,
    verbose=1
)
lstm_test_48_metrics = calculate_metrics(
    y_test_48,
    lstm_test_pred_48,
    scaler
)
lstm_test_48_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# {'MAE': 2308.3360503263216,
#  'MSE': 9514607.470964897,
#  'RMSE': np.float64(3084.5757359748677),
#  'MAPE': np.float64(7.053092218017552),
#  'R2': 0.7739756265822644,
#  'Bias': np.float64(-1391.0876894725075)}

# %%
lstm_test_pred_168 = lstm_168.predict(
    X_test_168,
    verbose=1
)
lstm_test_168_metrics = calculate_metrics(
    y_test_168,
    lstm_test_pred_168,
    scaler
)
lstm_test_168_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step
# {'MAE': 2269.6857995207133,
#  'MSE': 9272106.960321829,
#  'RMSE': np.float64(3045.0134581511834),
#  'MAPE': np.float64(6.956443775499296),
#  'R2': 0.7797363504102146,
#  'Bias': np.float64(-1362.6671037940018)}

# %%
gru_test_pred_24 = gru_24.predict(
    X_test_24,
    verbose=1
)
gru_test_24_metrics = calculate_metrics(
    y_test_24,
    gru_test_pred_24,
    scaler
)
gru_test_24_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# {'MAE': 2173.8285155638687,
#  'MSE': 9108020.165626328,
#  'RMSE': np.float64(3017.9496625401703),
#  'MAPE': np.float64(6.557067622561415),
#  'R2': 0.7836343162559264,
#  'Bias': np.float64(-1372.6798178861186)}

# %%
gru_test_pred_48 = gru_48.predict(
    X_test_48,
    verbose=1
)
gru_test_48_metrics = calculate_metrics(
    y_test_48,
    gru_test_pred_48,
    scaler
)
gru_test_48_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step
# {'MAE': 2453.827046654053,
#  'MSE': 10999578.256426513,
#  'RMSE': np.float64(3316.561209510012),
#  'MAPE': np.float64(7.3586410530122075),
#  'R2': 0.7386993850397884,
#  'Bias': np.float64(-1838.5354055222808)}

# %%
gru_test_pred_168 = gru_168.predict(
    X_test_168,
    verbose=1
)
gru_test_168_metrics = calculate_metrics(
    y_test_168,
    gru_test_pred_168,
    scaler
)
gru_test_168_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 14s 15ms/step
# {'MAE': 2695.1709555334796,
#  'MSE': 12729028.552776646,
#  'RMSE': np.float64(3567.776415749261),
#  'MAPE': np.float64(8.140812712966211),
#  'R2': 0.6976154075049785,
#  'Bias': np.float64(-1904.2509673675825)}

# %%
bilstm_test_pred_24 = bilstm_24.predict(
    X_test_24,
    verbose=1
)
bilstm_test_24_metrics = calculate_metrics(
    y_test_24,
    bilstm_test_pred_24,
    scaler
)
bilstm_test_24_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# {'MAE': 2372.9835287647306,
#  'MSE': 10751045.179458633,
#  'RMSE': np.float64(3278.878646650198),
#  'MAPE': np.float64(7.130052485334377),
#  'R2': 0.744603415570388,
#  'Bias': np.float64(-1589.1788157466613)}

# %%
bilstm_test_pred_48 = bilstm_48.predict(
    X_test_48,
    verbose=1
)
bilstm_test_48_metrics = calculate_metrics(
    y_test_48,
    bilstm_test_pred_48,
    scaler
)
bilstm_test_48_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# {'MAE': 2317.294023142612,
#  'MSE': 9808992.152588788,
#  'RMSE': np.float64(3131.931058083621),
#  'MAPE': np.float64(7.02175840761659),
#  'R2': 0.7669823676999753,
#  'Bias': np.float64(-1345.1529074105058)}

# %%
bilstm_test_pred_168 = bilstm_168.predict(
    X_test_168,
    verbose=1
)
bilstm_test_168_metrics = calculate_metrics(
    y_test_168,
    bilstm_test_pred_168,
    scaler
)
bilstm_test_168_metrics
# Out:
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step
# {'MAE': 2469.364654736257,
#  'MSE': 11166710.620793516,
#  'RMSE': np.float64(3341.6628526518825),
#  'MAPE': np.float64(7.408726650027135),
#  'R2': 0.7347290701267293,
#  'Bias': np.float64(-1938.9544069689252)}

# %%
test_results = pd.DataFrame([
    {
        "Model": "RNN",
        "Lookback": "24 hours",
        **rnn_test_24_metrics
    },
    {
        "Model": "RNN",
        "Lookback": "48 hours",
        **rnn_test_48_metrics
    },
    {
        "Model": "RNN",
        "Lookback": "168 hours",
        **rnn_test_168_metrics
    },

    {
        "Model": "LSTM",
        "Lookback": "24 hours",
        **lstm_test_24_metrics
    },
    {
        "Model": "LSTM",
        "Lookback": "48 hours",
        **lstm_test_48_metrics
    },
    {
        "Model": "LSTM",
        "Lookback": "168 hours",
        **lstm_test_168_metrics
    },

    {
        "Model": "GRU",
        "Lookback": "24 hours",
        **gru_test_24_metrics
    },
    {
        "Model": "GRU",
        "Lookback": "48 hours",
        **gru_test_48_metrics
    },
    {
        "Model": "GRU",
        "Lookback": "168 hours",
        **gru_test_168_metrics
    },

    {
        "Model": "Bi-LSTM",
        "Lookback": "24 hours",
        **bilstm_test_24_metrics
    },
    {
        "Model": "Bi-LSTM",
        "Lookback": "48 hours",
        **bilstm_test_48_metrics
    },
    {
        "Model": "Bi-LSTM",
        "Lookback": "168 hours",
        **bilstm_test_168_metrics
    }
])
test_results
# Out:
#       Model   Lookback          MAE           MSE         RMSE      MAPE  \
# 0       RNN   24 hours  2181.119019  9.167740e+06  3027.827602  6.664844
# 1       RNN   48 hours  2207.665843  8.984924e+06  2997.486316  6.807561
# 2       RNN  168 hours  2215.833608  9.626967e+06  3102.735359  6.679372
# 3      LSTM   24 hours  2253.035396  1.001697e+07  3164.959125  6.703247
# 4      LSTM   48 hours  2308.336050  9.514607e+06  3084.575736  7.053092
# 5      LSTM  168 hours  2269.685800  9.272107e+06  3045.013458  6.956444
# 6       GRU   24 hours  2173.828516  9.108020e+06  3017.949663  6.557068
# 7       GRU   48 hours  2453.827047  1.099958e+07  3316.561210  7.358641
# 8       GRU  168 hours  2695.170956  1.272903e+07  3567.776416  8.140813
# 9   Bi-LSTM   24 hours  2372.983529  1.075105e+07  3278.878647  7.130052
# 10  Bi-LSTM   48 hours  2317.294023  9.808992e+06  3131.931058  7.021758
# 11  Bi-LSTM  168 hours  2469.364655  1.116671e+07  3341.662853  7.408727
#
#           R2         Bias
# 0   0.782216  -970.745085
# 1   0.786559 -1133.319603
# 2   0.771306 -1378.126317
# 3   0.762042 -1544.931532
# 4   0.773976 -1391.087689
# 5   0.779736 -1362.667104
# 6   0.783634 -1372.679818
# 7   0.738699 -1838.535406
# 8   0.697615 -1904.250967
# 9   0.744603 -1589.178816
# 10  0.766982 -1345.152907
# 11  0.734729 -1938.954407

# %%
test_results_sorted = test_results.sort_values(
    by="RMSE",
    ascending=True
).reset_index(drop=True)
test_results_sorted
# Out:
#       Model   Lookback          MAE           MSE         RMSE      MAPE  \
# 0       RNN   48 hours  2207.665843  8.984924e+06  2997.486316  6.807561
# 1       GRU   24 hours  2173.828516  9.108020e+06  3017.949663  6.557068
# 2       RNN   24 hours  2181.119019  9.167740e+06  3027.827602  6.664844
# 3      LSTM  168 hours  2269.685800  9.272107e+06  3045.013458  6.956444
# 4      LSTM   48 hours  2308.336050  9.514607e+06  3084.575736  7.053092
# 5       RNN  168 hours  2215.833608  9.626967e+06  3102.735359  6.679372
# 6   Bi-LSTM   48 hours  2317.294023  9.808992e+06  3131.931058  7.021758
# 7      LSTM   24 hours  2253.035396  1.001697e+07  3164.959125  6.703247
# 8   Bi-LSTM   24 hours  2372.983529  1.075105e+07  3278.878647  7.130052
# 9       GRU   48 hours  2453.827047  1.099958e+07  3316.561210  7.358641
# 10  Bi-LSTM  168 hours  2469.364655  1.116671e+07  3341.662853  7.408727
# 11      GRU  168 hours  2695.170956  1.272903e+07  3567.776416  8.140813
#
#           R2         Bias
# 0   0.786559 -1133.319603
# 1   0.783634 -1372.679818
# 2   0.782216  -970.745085
# 3   0.779736 -1362.667104
# 4   0.773976 -1391.087689
# 5   0.771306 -1378.126317
# 6   0.766982 -1345.152907
# 7   0.762042 -1544.931532
# 8   0.744603 -1589.178816
# 9   0.738699 -1838.535406
# 10  0.734729 -1938.954407
# 11  0.697615 -1904.250967

# %%
validation_results = all_results.rename(
    columns={
        "MAE": "Val_MAE",
        "MSE": "Val_MSE",
        "RMSE": "Val_RMSE",
        "MAPE": "Val_MAPE",
        "R2": "Val_R2",
        "Bias": "Val_Bias"
    }
)

# %%
test_results_compare = test_results.rename(
    columns={
        "MAE": "Test_MAE",
        "MSE": "Test_MSE",
        "RMSE": "Test_RMSE",
        "MAPE": "Test_MAPE",
        "R2": "Test_R2",
        "Bias": "Test_Bias"
    }
)

# %%
final_comparison = pd.merge(
    validation_results,
    test_results_compare,
    on=["Model", "Lookback"]
)
final_comparison
# Out:
#       Model   Lookback      Val_MAE       Val_MSE     Val_RMSE   Val_MAPE  \
# 0       RNN   24 hours  2687.357066  1.280694e+07  3578.678163   7.773717
# 1       RNN   48 hours  2684.731908  1.218540e+07  3490.759742   7.833662
# 2       RNN  168 hours  2903.992579  1.447754e+07  3804.935639   8.307286
# 3      LSTM   24 hours  2969.424797  1.526177e+07  3906.631583   8.398609
# 4      LSTM   48 hours  3026.738221  1.504499e+07  3878.786658   8.763176
# 5      LSTM  168 hours  2936.470673  1.508462e+07  3883.892886   8.457236
# 6       GRU   24 hours  2919.180068  1.474307e+07  3839.670798   8.278844
# 7       GRU   48 hours  3261.995561  1.732204e+07  4161.975741   9.331502
# 8       GRU  168 hours  3989.528201  2.495127e+07  4995.124337  11.367106
# 9   Bi-LSTM   24 hours  3062.080161  1.535503e+07  3918.549211   8.694062
# 10  Bi-LSTM   48 hours  2857.792307  1.402632e+07  3745.173017   8.222600
# 11  Bi-LSTM  168 hours  3145.692199  1.634906e+07  4043.397634   8.987282
#
#       Val_R2     Val_Bias     Test_MAE      Test_MSE    Test_RMSE  Test_MAPE  \
# 0   0.583699 -1366.219501  2181.119019  9.167740e+06  3027.827602   6.664844
# 1   0.603903 -1552.584977  2207.665843  8.984924e+06  2997.486316   6.807561
# 2   0.529395 -2292.037082  2215.833608  9.626967e+06  3102.735359   6.679372
# 3   0.503903 -2507.726473  2253.035396  1.001697e+07  3164.959125   6.703247
# 4   0.510949 -2363.282008  2308.336050  9.514607e+06  3084.575736   7.053092
# 5   0.509661 -2169.486352  2269.685800  9.272107e+06  3045.013458   6.956444
# 6   0.520763 -2329.924394  2173.828516  9.108020e+06  3017.949663   6.557068
# 7   0.436932 -2844.605886  2453.827047  1.099958e+07  3316.561210   7.358641
# 8   0.188937 -3560.851506  2695.170956  1.272903e+07  3567.776416   8.140813
# 9   0.500871 -2565.291698  2372.983529  1.075105e+07  3278.878647   7.130052
# 10  0.544062 -1913.283977  2317.294023  9.808992e+06  3131.931058   7.021758
# 11  0.468559 -2827.339774  2469.364655  1.116671e+07  3341.662853   7.408727
#
#      Test_R2    Test_Bias
# 0   0.782216  -970.745085
# 1   0.786559 -1133.319603
# 2   0.771306 -1378.126317
# 3   0.762042 -1544.931532
# 4   0.773976 -1391.087689
# 5   0.779736 -1362.667104
# 6   0.783634 -1372.679818
# 7   0.738699 -1838.535406
# 8   0.697615 -1904.250967
# 9   0.744603 -1589.178816
# 10  0.766982 -1345.152907
# 11  0.734729 -1938.954407

# %%
best_test_model = test_results.loc[
    test_results["RMSE"].idxmin()
]
print("Best Test Model:")
print(best_test_model)
# Out:
# Best Test Model:
# Model                  RNN
# Lookback          48 hours
# MAE            2207.665843
# MSE         8984924.213966
# RMSE           2997.486316
# MAPE              6.807561
# R2                0.786559
# Bias          -1133.319603
# Name: 1, dtype: object

# %%
best_test_r2 = test_results.loc[
    test_results["R2"].idxmax()
]
print("Best Test R²:")
print(best_test_r2)
# Out:
# Best Test R²:
# Model                  RNN
# Lookback          48 hours
# MAE            2207.665843
# MSE         8984924.213966
# RMSE           2997.486316
# MAPE              6.807561
# R2                0.786559
# Bias          -1133.319603
# Name: 1, dtype: object
