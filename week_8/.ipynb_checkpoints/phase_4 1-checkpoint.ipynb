# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
df = pd.read_csv("PJME_preprocessed.csv",)

# %%
print("Shape:", df.shape)
print("Start:", df.index.min())
print("End:", df.index.max())
# Out:
# Shape: (145224, 24)
# Start: 0
# End: 145223

# %%
target = "PJME_MW"

# %%
print(df[target].describe())
# Out:
# count    145224.000000
# mean      32078.417972
# std        6466.680687
# min       14544.000000
# 25%       27569.000000
# 50%       31419.000000
# 75%       35647.000000
# max       62009.000000
# Name: PJME_MW, dtype: float64

# %%
print(
    "Missing values:",
    df[target].isnull().sum()
)
# Out:
# Missing values: 0

# %%
n = len(df)
test_size = int(n * 0.20)
test_start = n - test_size
print("Total observations:", n)
print("Test observations:", test_size)
# Out:
# Total observations: 145224
# Test observations: 29044

# %%
validation_hours = 60 * 24
validation_start = test_start - validation_hours
print("Validation observations:", validation_hours)
# Out:
# Validation observations: 1440

# %%
train = df.iloc[:validation_start].copy()
validation = df.iloc[
    validation_start:test_start
].copy()
test = df.iloc[test_start:].copy()

# %%
print("Train:")
print(train.index.min(), "→", train.index.max())

print("\nValidation:")
print(validation.index.min(), "→", validation.index.max())

print("\nTest:")
print(test.index.min(), "→", test.index.max())
# Out:
# Train:
# 0 → 114739
#
# Validation:
# 114740 → 116179
#
# Test:
# 116180 → 145223

# %%
print("\nTrain size:", len(train))
print("Validation size:", len(validation))
print("Test size:", len(test))
# Out:
# Train size: 114740
# Validation size: 1440
# Test size: 29044

# %%
plt.figure(figsize=(16, 6))
plt.plot(
    train.index,
    train[target],
    label="Train"
)
plt.plot(
    validation.index,
    validation[target],
    label="Validation"
)
plt.plot(
    test.index,
    test[target],
    label="Test"
)
plt.title("Chronological Train, Validation and Test Split")
plt.xlabel("Date")
plt.ylabel("Demand (MW)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
naive_validation_pred = (
    df[target]
    .shift(1)
    .loc[validation.index]
)

# %%
naive_test_pred = (
    df[target]
    .shift(1)
    .loc[test.index]
)

# %%
moving_avg = (
    df[target]
    .shift(1)
    .rolling(window=24)
    .mean()
)

# %%
moving_validation_pred = (moving_avg.loc[validation.index])

# %%
moving_test_pred = (moving_avg.loc[test.index])

# %%
previous_day_pred = (
    df[target]
    .shift(24)
)

# %%
previous_day_validation_pred = (
    previous_day_pred.loc[validation.index]
)

# %%
previous_day_test_pred = (
    previous_day_pred.loc[test.index]
)

# %%
previous_week_pred = (
    df[target]
    .shift(168)
)

# %%
previous_week_validation_pred = (
    previous_week_pred.loc[validation.index]
)

# %%
previous_week_test_pred = (
    previous_week_pred.loc[test.index]
)

# %%
baseline_predictions = pd.DataFrame({
    "Actual": validation[target],
    "Naive": naive_validation_pred,
    "Moving_Average": moving_validation_pred,
    "Previous_Day": previous_day_validation_pred,
    "Previous_Week": previous_week_validation_pred
})
baseline_predictions.head(20)
# Out:
#          Actual    Naive  Moving_Average  Previous_Day  Previous_Week
# 114740  39406.0  40458.0    34288.166667       33529.0        41789.0
# 114741  37578.0  39406.0    34533.041667       32207.0        40172.0
# 114742  35044.0  37578.0    34756.833333       30506.0        37764.0
# 114743  32804.0  35044.0    34945.916667       28728.0        35684.0
# 114744  31376.0  32804.0    35115.750000       27417.0        34382.0
# 114745  30704.0  31376.0    35280.708333       26795.0        33845.0
# 114746  30439.0  30704.0    35443.583333       26649.0        33722.0
# 114747  30627.0  30439.0    35601.500000       26935.0        33959.0
# 114748  31434.0  30627.0    35755.333333       28031.0        34923.0
# 114749  33622.0  31434.0    35897.125000       30395.0        37193.0
# 114750  36980.0  33622.0    36031.583333       34117.0        40687.0
# 114751  38882.0  36980.0    36150.875000       36207.0        42160.0
# 114752  39330.0  38882.0    36262.333333       36690.0        41956.0
# 114753  39071.0  39330.0    36372.333333       37166.0        41347.0
# 114754  38609.0  39071.0    36451.708333       37603.0        40553.0
# 114755  37897.0  38609.0    36493.625000       37822.0        39213.0
# 114756  36970.0  37897.0    36496.750000       37827.0        37987.0
# 114757  36198.0  36970.0    36461.041667       37820.0        37235.0
# 114758  35497.0  36198.0    36393.458333       37698.0        36637.0
# 114759  35365.0  35497.0    36301.750000       37863.0        36554.0

# %%
print(
    baseline_predictions.isnull().sum()
)
# Out:
# Actual            0
# Naive             0
# Moving_Average    0
# Previous_Day      0
# Previous_Week     0
# dtype: int64

# %%
baseline_predictions = (
    baseline_predictions.dropna()
)

# %%
def calculate_metrics(actual, predicted):
    mae = mean_absolute_error(
        actual,
        predicted
    )
    mse = mean_squared_error(
        actual,
        predicted
    )
    rmse = np.sqrt(mse)
    mape = np.mean(
        np.abs(
            (actual - predicted) / actual
        )
    ) * 100
    r2 = r2_score(
        actual,
        predicted
    )
    bias = np.mean(
        predicted - actual
    )
    return {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "Bias": bias
    }

# %%
baseline_results = []
metrics = calculate_metrics(
    baseline_predictions["Actual"],
    baseline_predictions["Naive"]
)
metrics["Model"] = "Naive"
baseline_results.append(metrics)

# %%
metrics = calculate_metrics(
    baseline_predictions["Actual"],
    baseline_predictions["Moving_Average"]
)
metrics["Model"] = "Moving Average"
baseline_results.append(metrics)

# %%
metrics = calculate_metrics(
    baseline_predictions["Actual"],
    baseline_predictions["Previous_Day"]
)
metrics["Model"] = "Previous Day"
baseline_results.append(metrics)

# %%
metrics = calculate_metrics(
    baseline_predictions["Actual"],
    baseline_predictions["Previous_Week"]
)
metrics["Model"] = "Previous Week"
baseline_results.append(metrics)

# %%
baseline_results_df = pd.DataFrame(
    baseline_results
)
baseline_results_df = baseline_results_df[
    [
        "Model",
        "MAE",
        "MSE",
        "RMSE",
        "MAPE",
        "R2",
        "Bias"
    ]
]
baseline_results_df
# Out:
#             Model          MAE           MSE         RMSE       MAPE  \
# 0           Naive   953.077083  1.540271e+06  1241.076619   2.888684
# 1  Moving Average  2550.131973  9.774786e+06  3126.465496   7.943250
# 2    Previous Day  2459.717361  1.002802e+07  3166.705087   7.329775
# 3   Previous Week  3583.018056  1.973139e+07  4442.002433  10.922560
#
#          R2        Bias
# 0  0.949514    7.481250
# 1  0.679610   57.267390
# 2  0.671309   78.384028
# 3  0.353260  939.450000

# %%
baseline_results_df.sort_values(
    "RMSE"
)
# Out:
#             Model          MAE           MSE         RMSE       MAPE  \
# 0           Naive   953.077083  1.540271e+06  1241.076619   2.888684
# 1  Moving Average  2550.131973  9.774786e+06  3126.465496   7.943250
# 2    Previous Day  2459.717361  1.002802e+07  3166.705087   7.329775
# 3   Previous Week  3583.018056  1.973139e+07  4442.002433  10.922560
#
#          R2        Bias
# 0  0.949514    7.481250
# 1  0.679610   57.267390
# 2  0.671309   78.384028
# 3  0.353260  939.450000

# %%
baseline_results_df.sort_values(
    "R2",
    ascending=False
)
# Out:
#             Model          MAE           MSE         RMSE       MAPE  \
# 0           Naive   953.077083  1.540271e+06  1241.076619   2.888684
# 1  Moving Average  2550.131973  9.774786e+06  3126.465496   7.943250
# 2    Previous Day  2459.717361  1.002802e+07  3166.705087   7.329775
# 3   Previous Week  3583.018056  1.973139e+07  4442.002433  10.922560
#
#          R2        Bias
# 0  0.949514    7.481250
# 1  0.679610   57.267390
# 2  0.671309   78.384028
# 3  0.353260  939.450000

# %%
plt.figure(figsize=(16, 6))
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Actual"],
    label="Actual"
)
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Naive"],
    label="Naive"
)
plt.title("Actual vs Naive Forecast")
plt.xlabel("Date")
plt.ylabel("Demand (MW)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 6))
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Actual"],
    label="Actual"
)
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Previous_Day"],
    label="Previous Day"
)
plt.title("Actual vs Previous-Day Forecast")
plt.xlabel("Date")
plt.ylabel("Demand (MW)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 6))
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Actual"],
    label="Actual"
)
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Previous_Week"],
    label="Previous Week"
)
plt.title("Actual vs Previous-Week Forecast")
plt.xlabel("Date")
plt.ylabel("Demand (MW)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 7))
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Actual"],
    label="Actual",
    linewidth=2
)
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Naive"],
    label="Naive",
    alpha=0.7
)
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Moving_Average"],
    label="Moving Average",
    alpha=0.7
)
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Previous_Day"],
    label="Previous Day",
    alpha=0.7
)
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Previous_Week"],
    label="Previous Week",
    alpha=0.7
)
plt.title("Baseline Forecast Comparison")
plt.xlabel("Date")
plt.ylabel("Demand (MW)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
best_baseline = baseline_results_df.loc[
    baseline_results_df["RMSE"].idxmin()
]
print(best_baseline)
# Out:
# Model             Naive
# MAE          953.077083
# MSE      1540271.175347
# RMSE        1241.076619
# MAPE           2.888684
# R2             0.949514
# Bias            7.48125
# Name: 0, dtype: object

# %%
baseline_predictions["Previous_Day_Error"] = (
    baseline_predictions["Actual"]
    - baseline_predictions["Previous_Day"]
)

# %%
plt.figure(figsize=(16, 5))
plt.plot(
    baseline_predictions.index,
    baseline_predictions["Previous_Day_Error"]
)
plt.axhline(
    0,
    linestyle="--"
)
plt.title("Previous-Day Forecast Error")
plt.xlabel("Date")
plt.ylabel("Forecast Error (MW)")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(
    baseline_predictions["Previous_Day_Error"],
    bins=50,
    kde=True
)
plt.title("Previous-Day Forecast Error Distribution")
plt.xlabel("Forecast Error (MW)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
bias = np.mean(
    baseline_predictions["Previous_Day"]
    - baseline_predictions["Actual"]
)

print("Previous-Day Forecast Bias:", bias)
# Out:
# Previous-Day Forecast Bias: 78.38402777777777

# %%
bias_results = {
    "Naive": np.mean(
        baseline_predictions["Naive"]
        - baseline_predictions["Actual"]
    ),

    "Moving Average": np.mean(
        baseline_predictions["Moving_Average"]
        - baseline_predictions["Actual"]
    ),

    "Previous Day": np.mean(
        baseline_predictions["Previous_Day"]
        - baseline_predictions["Actual"]
    ),

    "Previous Week": np.mean(
        baseline_predictions["Previous_Week"]
        - baseline_predictions["Actual"]
    )
}
bias_df = pd.DataFrame(
    bias_results.items(),
    columns=["Model", "Bias"]
)
bias_df
# Out:
#             Model        Bias
# 0           Naive    7.481250
# 1  Moving Average   57.267390
# 2    Previous Day   78.384028
# 3   Previous Week  939.450000

# %%
baseline_results_df.to_csv("baseline_results.csv",)
