# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
phase5_results = pd.read_csv("phase5_validation_results.csv")

phase5_results
# Out:
#       Model   Lookback          MAE           MSE         RMSE      MAPE  \
# 0       RNN   24 hours  2934.691966  1.507680e+07  3882.885505  8.381019
# 1       RNN   48 hours  2804.554276  1.337679e+07  3657.429797  8.108753
# 2       RNN  168 hours  3091.808792  1.631260e+07  4038.886552  9.044437
# 3      LSTM   24 hours  2927.467063  1.455961e+07  3815.705578  8.338201
# 4      LSTM   48 hours  2975.498900  1.507415e+07  3882.544249  8.572470
# 5      LSTM  168 hours  2753.207870  1.250400e+07  3536.100119  8.019766
# 6       GRU   24 hours  2995.379049  1.501655e+07  3875.118779  8.514461
# 7       GRU   48 hours  2941.408518  1.399695e+07  3741.250010  8.494127
# 8       GRU  168 hours  2907.838106  1.410485e+07  3755.642477  8.411296
# 9   Bi-LSTM   24 hours  2991.414989  1.523597e+07  3903.328432  8.521060
# 10  Bi-LSTM   48 hours  2826.661405  1.388515e+07  3726.277780  8.073060
# 11  Bi-LSTM  168 hours  2828.005018  1.353820e+07  3679.429539  8.128915
#
# ...

# %%
phase5_results.sort_values(
    by="R2",
    ascending=False
)
best_phase5 = phase5_results.loc[
    phase5_results["R2"].idxmax()
]

best_phase5
# Out:
# Model                  LSTM
# Lookback          168 hours
# MAE              2753.20787
# MSE         12504004.051972
# RMSE            3536.100119
# MAPE               8.019766
# R2                 0.593546
# Bias           -1905.002036
# Name: 5, dtype: object

# %%
phase6_results = pd.read_csv("phase6_rnn_final_comparison.csv")

phase6_results
# Out:
#                                            Experiment           MAE  \
# 0                             Phase 5 RNN-48 Baseline   2213.295950
# 1                              RNN-48 + Time Features   2338.989995
# 2                        RNN-48 + Time + Lag Features   2894.430283
# 3              RNN-48 + Time + Lag + Rolling Features   2045.282073
# 4              RNN-48 + Time + Lag + Rolling Features   2045.282073
# 5                                    RNN-48 + Dropout   2236.203850
# 6                        RNN-48 + Batch Normalization   4421.516925
# 7                                    RNN-48 + RMSprop   2897.984130
# 8                    RNN-48 + RMSprop + LR Scheduling  18707.087116
# 9                    RNN-48 + RMSprop + LR Scheduling   2102.411521
# 10  RNN-48 + RMSprop + LR Scheduling + Early Stopping   2385.324975
# 11  RNN-48 + RMSprop + LR Scheduling + Early Stopp...   2326.750397
# 12                          RNN-48 + 2 Layers (64-32)   3003.001419
# ...

# %%
phase6_results.sort_values(
    by="R2",
    ascending=False
)
phase6_best1 = phase6_results.loc[
    phase6_results["R2"].idxmax()
]

phase6_best1
# Out:
# Experiment    RNN-48 + Time + Lag + Rolling Features
# MAE                                      2045.282073
# RMSE                                     2569.550332
# MAPE                                        6.362701
# R2                                          0.799563
# Bias                                      614.004363
# Name: 3, dtype: object

# %%
phase6_results = pd.read_csv("phase6_LSTM_final_comparison.csv")

phase6_results
# Out:
#                                            Experiment          MAE  \
# 0                           Phase 5 LSTM-168 Baseline  2115.964600
# 1                            LSTM-168 + Time Features  1633.993795
# 2                      LSTM-168 + Time + Lag Features  1699.106699
# 3            LSTM-168 + Time + Lag + Rolling Features  1620.934066
# 4                                  LSTM-168 + Dropout  1832.706852
# 5                      LSTM-168 + Batch Normalization  4388.166616
# 6                                  LSTM-168 + RMSprop  2546.784354
# 7                  LSTM-168 + RMSprop + LR Scheduling  2598.370160
# 8   LSTM-168 + RMSprop + LR Scheduling + Early Sto...  2634.539679
# 9   LSTM-168 + RMSprop + LR Scheduling + Early Sto...  3135.007312
# 10                        LSTM-168 + 2 Layers (64-32)  2774.917854
# 11                     LSTM-168 Hyperparameter Tuning  2401.744759
#
#            RMSE       MAPE        R2         Bias
# ...

# %%
phase6_results.sort_values(
    by="R2",
    ascending=False
)
phase6_best2 = phase6_results.loc[
    phase6_results["R2"].idxmax()
]

phase6_best2
# Out:
# Experiment    LSTM-168 + Time + Lag + Rolling Features
# MAE                                        1620.934066
# RMSE                                       2178.920978
# MAPE                                          4.872283
# R2                                            0.855873
# Bias                                         -388.0722
# Name: 3, dtype: object

# %%
phase6_results = pd.read_csv("phase6_gru_final_comparison.csv")

phase6_results
# Out:
#                                            Experiment          MAE  \
# 0                            Phase 5 GRU-168 Baseline  2152.241307
# 1                             GRU-168 + Time Features  1675.188759
# 2                       GRU-168 + Time + Lag Features  1688.835670
# 3             GRU-168 + Time + Lag + Rolling Features  1590.667643
# 4                                   GRU-168 + Dropout  1780.415825
# 5                       GRU-168 + Batch Normalization  5030.354422
# 6                                   GRU-168 + RMSprop  2643.639751
# 7                   GRU-168 + RMSprop + LR Scheduling  2706.275406
# 8   GRU-168 + RMSprop + LR Scheduling + Early Stop...  2707.845181
# 9   GRU-168 + RMSprop + LR Scheduling + Early Stop...  3117.956332
# 10  GRU-168 + RMSprop + LR Scheduling + Early Stop...  3117.956332
# 11                         GRU-168 + 2 Layers (64-32)  2906.787300
# 12                         GRU-168 + 2 Layers (64-32)  2906.787300
# ...

# %%
phase6_results.sort_values(
    by="R2",
    ascending=False
)
phase6_best3 = phase6_results.loc[
    phase6_results["R2"].idxmax()
]

phase6_best3
# Out:
# Experiment    GRU-168 + Time + Lag + Rolling Features
# MAE                                       1590.667643
# RMSE                                      2171.728658
# MAPE                                         4.752545
# R2                                           0.856823
# Bias                                      -449.427243
# Name: 3, dtype: object

# %%
phase6_results = pd.read_csv("phase6_bilstm_final_comparison.csv")

phase6_results
# Out:
#                                            Experiment          MAE  \
# 0                          Phase 5 bilstm-48 Baseline  2120.811443
# 1                           bilstm-48 + Time Features  1707.111232
# 2                     bilstm-48 + Time + Lag Features  1699.733155
# 3           bilstm-48 + Time + Lag + Rolling Features  1678.903587
# 4                                 bilstm-48 + Dropout  1749.704313
# 5                     bilstm-48 + Batch Normalization  4996.753740
# 6                                 bilstm-48 + RMSprop  2822.337342
# 7                 bilstm-48 + RMSprop + LR Scheduling  2814.531897
# 8   bilstm-48 + RMSprop + LR Scheduling + Early St...  2799.251553
# 9   bilstm-48 + RMSprop + LR Scheduling + Early St...  3685.190514
# 10                       bilstm-48 + 2 Layers (64-32)  3019.188058
# 11                    bilstm-48 Hyperparameter Tuning  2530.466742
#
#            RMSE       MAPE        R2         Bias
# ...

# %%
phase6_results.sort_values(
    by="R2",
    ascending=False
)
phase6_best4 = phase6_results.loc[
    phase6_results["R2"].idxmax()
]

phase6_best4
# Out:
# Experiment    bilstm-48 + Time + Lag + Rolling Features
# MAE                                         1678.903587
# RMSE                                        2189.625023
# MAPE                                            5.14593
# R2                                             0.854453
# Bias                                          206.55184
# Name: 3, dtype: object

# %%
phase6_results = pd.read_csv("phase7_validation_comparison.csv")

phase6_results
# Out:
#   Metric        30-Day        60-Day
# 0    MAE  1.407508e+03  1.703376e+03
# 1    MSE  3.283891e+06  5.376326e+06
# 2   RMSE  1.812151e+03  2.318691e+03
# 3   MAPE  4.758344e+00  4.995226e+00
# 4     R2  7.396601e-01  8.210248e-01
# 5   Bias  2.076982e+02 -4.037432e+02
